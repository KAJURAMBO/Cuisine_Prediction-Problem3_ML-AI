# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set()

# %%
data = pd.read_csv(r'C:\Users\rahma\ineauron_updated\restaurant_data.csv')

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)  order_date
# 0          Buffet    Banashankari  2022-03-23
# 1          Buffet    Banashankari  2022-04-16
# 2          Buffet    Banashankari  2022-03-14
# 3          Buffet    Banashankari  2022-05-09
# 4          Buffet    Banashankari  2022-03-19

# %%
data["approx_cost(for two people)"].isnull().sum()
# Out:
# 346

# %%
data["approx_cost(for two people)"].value_counts()
# Out:
# 300      7576
# 400      6562
# 500      4980
# 200      4857
# 600      3714
#          ...
# 60          1
# 5,000       1
# 3,700       1
# 469         1
# 160         1
# Name: approx_cost(for two people), Length: 70, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51711                                            Bhagini           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...          ...     ...    ...                               ...
# 51705        Yes  3.8 /5    128    +91 7625087121\n+91 8050587483
# 51707         No  3.9 /5     77                      080 49435000
# 51708         No  2.8 /5    161      080 39451000\n+91 8884038484
# 51711         No  2.5 /5     81                      080 65951222
# 51715        Yes  4.3 /5    236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 51705                  Whitefield   Bar, Casual Dining
# 51707                  Whitefield     Fine Dining, Bar
# 51708                  Whitefield   Casual Dining, Bar
# 51711                  Whitefield   Casual Dining, Bar
# 51715  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51711                               Biryani, Andhra Meal
# 51715                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51705                       1,200
# 51707                       2,000
# 51708                       1,200
# 51711                         800
# 51715                       2,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51705  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 51707  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 51708  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city)  order_date
# 0              Buffet    Banashankari  2022-03-23
# 1              Buffet    Banashankari  2022-04-16
# 2              Buffet    Banashankari  2022-03-14
# 3              Buffet    Banashankari  2022-05-09
# 4              Buffet    Banashankari  2022-03-19
# ...               ...             ...         ...
# 51705   Pubs and bars      Whitefield  2022-05-24
# 51707   Pubs and bars      Whitefield  2022-05-16
# 51708   Pubs and bars      Whitefield  2022-03-22
# 51711   Pubs and bars      Whitefield  2022-03-30
# 51715   Pubs and bars      Whitefield  2022-05-18
#
# [23193 rows x 18 columns]

# %%
data["approx_cost(for two people)"].value_counts()
# Out:
# 400      2467
# 500      2271
# 600      2170
# 300      1688
# 800      1658
# 1,000    1242
# 700      1160
# 1,200     903
# 200       862
# 1,500     858
# 450       720
# 250       697
# 750       652
# 650       637
# 350       553
# 900       518
# 1,300     497
# 1,100     462
# 1,400     446
# 550       440
# 150       367
# 2,000     297
# 1,600     241
# 1,700     233
# 1,800     189
# 3,000     159
# 2,500     143
# 850       122
# 100       117
# 2,100      63
# 1,900      58
# 950        47
# 2,200      39
# 2,800      31
# 3,500      25
# 4,000      24
# 2,400      22
# 1,350      18
# 180        17
# 3,400      13
# 230        10
# 1,250       9
# 40          8
# 1,650       6
# 1,450       5
# 2,600       4
# 1,050       4
# 4,100       4
# 330         4
# 2,700       2
# 3,200       2
# 120         2
# 6,000       2
# 4,500       2
# 5,000       1
# 3,700       1
# 2,300       1
# Name: approx_cost(for two people), dtype: int64

# %%
data['approx_cost(for two people)'] = data['approx_cost(for two people)'].str.replace(',','')

# %%
data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51711                                            Bhagini           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...          ...     ...    ...                               ...
# 51705        Yes  3.8 /5    128    +91 7625087121\n+91 8050587483
# 51707         No  3.9 /5     77                      080 49435000
# 51708         No  2.8 /5    161      080 39451000\n+91 8884038484
# 51711         No  2.5 /5     81                      080 65951222
# 51715        Yes  4.3 /5    236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 51705                  Whitefield   Bar, Casual Dining
# 51707                  Whitefield     Fine Dining, Bar
# 51708                  Whitefield   Casual Dining, Bar
# 51711                  Whitefield   Casual Dining, Bar
# 51715  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51711                               Biryani, Andhra Meal
# 51715                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51705                        1200
# 51707                        2000
# 51708                        1200
# 51711                         800
# 51715                        2500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51705  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 51707  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 51708  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city)  order_date
# 0              Buffet    Banashankari  2022-03-23
# 1              Buffet    Banashankari  2022-04-16
# 2              Buffet    Banashankari  2022-03-14
# 3              Buffet    Banashankari  2022-05-09
# 4              Buffet    Banashankari  2022-03-19
# ...               ...             ...         ...
# 51705   Pubs and bars      Whitefield  2022-05-24
# 51707   Pubs and bars      Whitefield  2022-05-16
# 51708   Pubs and bars      Whitefield  2022-03-22
# 51711   Pubs and bars      Whitefield  2022-03-30
# 51715   Pubs and bars      Whitefield  2022-05-18
#
# [23193 rows x 18 columns]

# %%
data["approx_cost(for two people)"].isnull().sum()
# Out:
# 0

# %%
data['approx_cost(for two people)']=data["approx_cost(for two people)"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23193 entries, 0 to 51715
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  int32
#  13  reviews_list                 23193 non-null  object
#  14  menu_item                    23193 non-null  object
#  15  listed_in(type)              23193 non-null  object
#  16  listed_in(city)              23193 non-null  object
#  17  order_date                   23193 non-null  object
# dtypes: int32(1), int64(1), object(16)
# memory usage: 3.3+ MB

# %%
data['requirement']=data['votes']*data['approx_cost(for two people)']

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)', 'order_date', 'requirement'],
#       dtype='object')

# %%
data.drop(["url","online_order","book_table","rate",'phone','rest_type','reviews_list','listed_in(type)'] ,axis=1 ,inplace=True)

# %%
data.drop(['menu_item'],axis=1,inplace=True)

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  votes  \
# 0                                                  Jalsa    775
# 1                                         Spice Elephant    787
# 2                                        San Churro Cafe    918
# 3                                  Addhuri Udupi Bhojana     88
# 4                                          Grand Village    166
# ...                                                  ...    ...
# 51705                                 Izakaya Gastro Pub    128
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield     77
# 51708                             Keys Cafe - Keys Hotel    161
# 51711                                            Bhagini     81
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...    236
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51711                               Biryani, Andhra Meal
# 51715                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#        approx_cost(for two people) listed_in(city)  order_date  requirement
# 0                              800    Banashankari  2022-03-23       620000
# 1                              800    Banashankari  2022-04-16       629600
# 2                              800    Banashankari  2022-03-14       734400
# 3                              300    Banashankari  2022-05-09        26400
# 4                              600    Banashankari  2022-03-19        99600
# ...                            ...             ...         ...          ...
# 51705                         1200      Whitefield  2022-05-24       153600
# 51707                         2000      Whitefield  2022-05-16       154000
# 51708                         1200      Whitefield  2022-03-22       193200
# 51711                          800      Whitefield  2022-03-30        64800
# 51715                         2500      Whitefield  2022-05-18       590000
#
# [23193 rows x 10 columns]

# %%
data['cuisines'].value_counts()
# Out:
# North Indian                                                  1144
# North Indian, Chinese                                          777
# South Indian                                                   359
# Cafe                                                           273
# South Indian, North Indian, Chinese                            233
#                                                               ...
# Cafe, Salad, Healthy Food, Mexican                               1
# Biryani, Chettinad, Chinese                                      1
# North Indian, South Indian, Chinese, Desserts, Street Food       1
# North Indian, Chinese, South Indian, Juices                      1
# Thai, Chinese, Momos                                             1
# Name: cuisines, Length: 1687, dtype: int64

# %%
data["Day"] = pd.to_datetime(data.order_date,format="%Y/%m/%d").dt.day

# %%
data["Month"] = pd.to_datetime(data.order_date,format="%Y/%m/%d").dt. month

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  votes  \
# 0                                                  Jalsa    775
# 1                                         Spice Elephant    787
# 2                                        San Churro Cafe    918
# 3                                  Addhuri Udupi Bhojana     88
# 4                                          Grand Village    166
# ...                                                  ...    ...
# 51705                                 Izakaya Gastro Pub    128
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield     77
# 51708                             Keys Cafe - Keys Hotel    161
# 51711                                            Bhagini     81
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...    236
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51711                               Biryani, Andhra Meal
# 51715                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#        approx_cost(for two people) listed_in(city)  order_date  requirement  \
# 0                              800    Banashankari  2022-03-23       620000
# 1                              800    Banashankari  2022-04-16       629600
# 2                              800    Banashankari  2022-03-14       734400
# 3                              300    Banashankari  2022-05-09        26400
# 4                              600    Banashankari  2022-03-19        99600
# ...                            ...             ...         ...          ...
# 51705                         1200      Whitefield  2022-05-24       153600
# 51707                         2000      Whitefield  2022-05-16       154000
# 51708                         1200      Whitefield  2022-03-22       193200
# 51711                          800      Whitefield  2022-03-30        64800
# 51715                         2500      Whitefield  2022-05-18       590000
#
#        Day  Month
# 0       23      3
# 1       16      4
# 2       14      3
# 3        9      5
# 4       19      3
# ...    ...    ...
# 51705   24      5
# 51707   16      5
# 51708   22      3
# 51711   30      3
# 51715   18      5
#
# [23193 rows x 12 columns]

# %%
data['order_date'].value_counts()
# Out:
# 2022-05-17    297
# 2022-05-30    289
# 2022-03-28    282
# 2022-03-23    279
# 2022-04-18    278
#              ...
# 2022-04-29    229
# 2022-05-22    225
# 2022-03-10    216
# 2022-05-23    215
# 2022-03-30    214
# Name: order_date, Length: 91, dtype: int64

# %%
data.drop(['order_date'],axis=1,inplace=True)

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  votes  \
# 0                                                  Jalsa    775
# 1                                         Spice Elephant    787
# 2                                        San Churro Cafe    918
# 3                                  Addhuri Udupi Bhojana     88
# 4                                          Grand Village    166
# ...                                                  ...    ...
# 51705                                 Izakaya Gastro Pub    128
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield     77
# 51708                             Keys Cafe - Keys Hotel    161
# 51711                                            Bhagini     81
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...    236
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51711                               Biryani, Andhra Meal
# 51715                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#        approx_cost(for two people) listed_in(city)  requirement  Day  Month
# 0                              800    Banashankari       620000   23      3
# 1                              800    Banashankari       629600   16      4
# 2                              800    Banashankari       734400   14      3
# 3                              300    Banashankari        26400    9      5
# 4                              600    Banashankari        99600   19      3
# ...                            ...             ...          ...  ...    ...
# 51705                         1200      Whitefield       153600   24      5
# 51707                         2000      Whitefield       154000   16      5
# 51708                         1200      Whitefield       193200   22      3
# 51711                          800      Whitefield        64800   30      3
# 51715                         2500      Whitefield       590000   18      5
#
# [23193 rows x 11 columns]

# %%
sns.catplot(y="requirement",x="Month",data=data.sort_values("requirement",ascending=False),kind="boxen",height=6,aspect=3)

# %%
data.drop(['dish_liked'],axis=1,inplace=True)

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  votes  \
# 0                                                  Jalsa    775
# 1                                         Spice Elephant    787
# 2                                        San Churro Cafe    918
# 3                                  Addhuri Udupi Bhojana     88
# 4                                          Grand Village    166
# ...                                                  ...    ...
# 51705                                 Izakaya Gastro Pub    128
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield     77
# 51708                             Keys Cafe - Keys Hotel    161
# 51711                                            Bhagini     81
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...    236
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 51705     North Indian, Continental, Mediterranean
# 51707                                  Finger Food
# 51708           Chinese, Continental, North Indian
# 51711  Andhra, South Indian, Chinese, North Indian
# 51715                                  Finger Food
#
#        approx_cost(for two people) listed_in(city)  requirement  Day  Month
# 0                              800    Banashankari       620000   23      3
# 1                              800    Banashankari       629600   16      4
# 2                              800    Banashankari       734400   14      3
# 3                              300    Banashankari        26400    9      5
# 4                              600    Banashankari        99600   19      3
# ...                            ...             ...          ...  ...    ...
# 51705                         1200      Whitefield       153600   24      5
# 51707                         2000      Whitefield       154000   16      5
# 51708                         1200      Whitefield       193200   22      3
# 51711                          800      Whitefield        64800   30      3
# 51715                         2500      Whitefield       590000   18      5
#
# [23193 rows x 10 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap="Accent")
plt.show()

# %%
data.drop(['approx_cost(for two people)','votes'],axis=1,inplace=True)

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 51705                                 Izakaya Gastro Pub
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield
# 51708                             Keys Cafe - Keys Hotel
# 51711                                            Bhagini
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                           cuisines listed_in(city)  \
# 0                   North Indian, Mughlai, Chinese    Banashankari
# 1                      Chinese, North Indian, Thai    Banashankari
# 2                           Cafe, Mexican, Italian    Banashankari
# 3                       South Indian, North Indian    Banashankari
# 4                         North Indian, Rajasthani    Banashankari
# ...                                            ...             ...
# 51705     North Indian, Continental, Mediterranean      Whitefield
# 51707                                  Finger Food      Whitefield
# 51708           Chinese, Continental, North Indian      Whitefield
# 51711  Andhra, South Indian, Chinese, North Indian      Whitefield
# 51715                                  Finger Food      Whitefield
#
#        requirement  Day  Month
# 0           620000   23      3
# 1           629600   16      4
# 2           734400   14      3
# 3            26400    9      5
# 4            99600   19      3
# ...            ...  ...    ...
# 51705       153600   24      5
# 51707       154000   16      5
# 51708       193200   22      3
# 51711        64800   30      3
# 51715       590000   18      5
#
# [23193 rows x 8 columns]

# %%
data.drop(['Day'],axis=1,inplace=True)

# %%
data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 51705                                 Izakaya Gastro Pub
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield
# 51708                             Keys Cafe - Keys Hotel
# 51711                                            Bhagini
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
#                          location  \
# 0                    Banashankari
# 1                    Banashankari
# 2                    Banashankari
# 3                    Banashankari
# 4                    Basavanagudi
# ...                           ...
# 51705                  Whitefield
# 51707                  Whitefield
# 51708                  Whitefield
# 51711                  Whitefield
# 51715  ITPL Main Road, Whitefield
#
#                                           cuisines listed_in(city)  \
# 0                   North Indian, Mughlai, Chinese    Banashankari
# 1                      Chinese, North Indian, Thai    Banashankari
# 2                           Cafe, Mexican, Italian    Banashankari
# 3                       South Indian, North Indian    Banashankari
# 4                         North Indian, Rajasthani    Banashankari
# ...                                            ...             ...
# 51705     North Indian, Continental, Mediterranean      Whitefield
# 51707                                  Finger Food      Whitefield
# 51708           Chinese, Continental, North Indian      Whitefield
# 51711  Andhra, South Indian, Chinese, North Indian      Whitefield
# 51715                                  Finger Food      Whitefield
#
#        requirement  Month
# 0           620000      3
# 1           629600      4
# 2           734400      3
# 3            26400      5
# 4            99600      3
# ...            ...    ...
# 51705       153600      5
# 51707       154000      5
# 51708       193200      3
# 51711        64800      3
# 51715       590000      5
#
# [23193 rows x 7 columns]

# %%
data['cuisines'].value_counts()
# Out:
# North Indian                                                  1144
# North Indian, Chinese                                          777
# South Indian                                                   359
# Cafe                                                           273
# South Indian, North Indian, Chinese                            233
#                                                               ...
# Cafe, Salad, Healthy Food, Mexican                               1
# Biryani, Chettinad, Chinese                                      1
# North Indian, South Indian, Chinese, Desserts, Street Food       1
# North Indian, Chinese, South Indian, Juices                      1
# Thai, Chinese, Momos                                             1
# Name: cuisines, Length: 1687, dtype: int64

# %%
data.drop(['address','listed_in(city)'],axis=1,inplace=True)

# %%
data.head(50)
# Out:
#                                                  name              location  \
# 0                                               Jalsa          Banashankari
# 1                                      Spice Elephant          Banashankari
# 2                                     San Churro Cafe          Banashankari
# 3                               Addhuri Udupi Bhojana          Banashankari
# 4                                       Grand Village          Basavanagudi
# 5                                     Timepass Dinner          Basavanagudi
# 7                                              Onesta          Banashankari
# 8                                      Penthouse Cafe          Banashankari
# 9                                           Smacznego          Banashankari
# 10  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Banashankari
# 11                                       Cafe Shuffle          Banashankari
# 12                                   The Coffee Shack          Banashankari
# 13                                         Caf-Eleven          Banashankari
# 14                                    San Churro Cafe          Banashankari
# 15                                      Cafe Vivacity          Banashankari
# 16                                       Catch-up-ino          Banashankari
# 17                                   Kirthi's Biryani          Banashankari
# 18                                           T3H Cafe          Banashankari
# 20                                   The Vintage Cafe          Banashankari
# 21                                       Woodee Pizza          Banashankari
# 23                                       My Tea House          Banashankari
# 29                                   Srinathji's Cafe          Basavanagudi
# 30                                          Redberrys          Basavanagudi
# 31                                         Foodiction          Banashankari
# 33                                    Ovenstory Pizza          Banashankari
# 34                                             Faasos          Banashankari
# 35                                    Behrouz Biryani          Banashankari
# 37                                    Szechuan Dragon          Banashankari
# 38                                  Empire Restaurant             Jayanagar
# 40                                          Chaatimes          Basavanagudi
# 42                                         McDonald's          Banashankari
# 43                                     Domino's Pizza          Banashankari
# 44                                             Onesta          Banashankari
# 45                                           Hotboxit          Banashankari
# 46                                     Kitchen Garden    Kumaraswamy Layout
# 47                                             Recipe    Kumaraswamy Layout
# 48                                      Beijing Bites  Rajarajeshwari Nagar
# 49                                        Tasty Bytes    Kumaraswamy Layout
# 52                             Corner House Ice Cream          Banashankari
# 53                                  Biryanis And More             Jayanagar
# 54                                       Roving Feast          Banashankari
# 55                                          FreshMenu          Banashankari
# 57                                             Wamama          Banashankari
# 60                                      Peppy Peppers          Banashankari
# 61                                           Goa 0 Km    Kumaraswamy Layout
# 63                                               1947          Banashankari
# 65                                        Kabab Magic          Basavanagudi
# 67                                 Gustoes Beer House          Banashankari
# 71                                   The Biryani Cafe          Banashankari
# 74                                    Rolls On Wheels          Banashankari
#
#                                              cuisines  requirement  Month
# 0                      North Indian, Mughlai, Chinese       620000      3
# 1                         Chinese, North Indian, Thai       629600      4
# 2                              Cafe, Mexican, Italian       734400      3
# 3                          South Indian, North Indian        26400      5
# 4                            North Indian, Rajasthani        99600      3
# 5                                        North Indian       171600      4
# 7                                Pizza, Cafe, Italian      1533600      3
# 8                          Cafe, Italian, Continental       226800      5
# 9            Cafe, Mexican, Italian, Momos, Beverages       277200      3
# 10                                               Cafe       201000      5
# 11                         Cafe, Italian, Continental        90000      4
# 12                Cafe, Chinese, Continental, Italian        82000      3
# 13                                  Cafe, Continental       190800      3
# 14                             Cafe, Mexican, Italian       734400      4
# 15                                               Cafe        58500      5
# 16       Cafe, Fast Food, Continental, Chinese, Momos       106400      3
# 17                             Chinese, Cafe, Italian       100800      4
# 18                            Cafe, Italian, American        27900      3
# 20                         Cafe, French, North Indian        24800      3
# 21                  Cafe, Pizza, Fast Food, Beverages        90000      5
# 23                 Italian, Fast Food, Cafe, European        37200      3
# 29             North Indian, Cafe, Chinese, Fast Food        81400      3
# 30                                      Cafe, Italian       131400      5
# 31           North Indian, Fast Food, Chinese, Burger       253000      5
# 33                                              Pizza       129000      3
# 34                   North Indian, Biryani, Fast Food       207500      5
# 35                                            Biryani       149500      3
# 37                               Chinese, Thai, Momos       988200      3
# 38       North Indian, Mughlai, South Indian, Chinese      3663000      4
# 40                             Street Food, Fast Food        26600      5
# 42                                  Burger, Fast Food       143000      3
# 43                                   Pizza, Fast Food       432000      5
# 44                               Pizza, Cafe, Italian      1533600      3
# 45                 North Indian, Continental, Italian        14400      4
# 46                              North Indian, Chinese        73200      5
# 47              North Indian, Chinese, Biryani, Rolls       361800      3
# 48                                      Chinese, Thai       577150      3
# 49                North Indian, Chinese, Momos, Rolls        73500      5
# 52                                Ice Cream, Desserts       138000      3
# 53  Biryani, North Indian, Chinese, Andhra, South ...       463500      4
# 54    Italian, Continental, Fast Food, Chinese, Momos       471150      4
# 55  Healthy Food, Chinese, Biryani, North Indian, ...       282150      5
# 57  Asian, Korean, Indonesian, Japanese, Chinese, ...       283200      4
# 60                     Italian, North Indian, Mexican       195200      3
# 61      Goan, Seafood, North Indian, Chinese, Biryani       130400      4
# 63                              North Indian, Chinese       686800      5
# 65            North Indian, Kebab, Chinese, Fast Food       688000      5
# 67  Continental, Italian, Mexican, North Indian, C...      1041600      4
# 71                            Biryani, Chinese, Kebab       156000      5
# 74                            Fast Food, Rolls, Momos        89700      4

# %%
data1=data.assign(cuisines=data['cuisines'].str.split(',')).explode('cuisines')

# %%
data1['cuisines'].value_counts()
# Out:
#  Chinese          6025
# North Indian      5424
#  North Indian     4596
#  Continental      2863
# Cafe              2788
#                   ...
#  North Eastern       2
# Momos                2
#  Pan Asian           2
# Singaporean          1
#  Kashmiri            1
# Name: cuisines, Length: 174, dtype: int64

# %%
data1.head(10)
# Out:
#    name  location  cuisines  requirement  Month
# 0  1333         1       150       620000      3
# 0  1333         1        63       620000      3
# 0  1333         1        25       620000      3
# 1  2501         1       114       629600      4
# 1  2501         1        67       629600      4
# 1  2501         1        88       629600      4
# 2  2318         1       112       734400      3
# 2  2318         1        58       734400      3
# 2  2318         1        43       734400      3
# 3    71         1       164        26400      5

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data1['location']=le.fit_transform(data1['location'])
data1['name']=le.fit_transform(data1['name'])
data1['cuisines']=le.fit_transform(data1['cuisines'])

data1
# Out:
#        name  location  cuisines  requirement  Month
# 0      1333         1       150       620000      3
# 0      1333         1        63       620000      3
# 0      1333         1        25       620000      3
# 1      2501         1       114       629600      4
# 1      2501         1        67       629600      4
# ...     ...       ...       ...          ...    ...
# 51711   310        84        96        64800      3
# 51711   310        84        80        64800      3
# 51711   310        84        25        64800      3
# 51711   310        84        67        64800      3
# 51715   645        25       120       590000      5
#
# [66199 rows x 5 columns]

# %%
X = data1.drop('requirement',axis=1).values
y = data1['requirement'].values

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=33)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Model_fit_Random=RandomForestRegressor(n_estimators = 100, random_state = 0) ## Intialising the model

# %%
Model_fit_Random.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = Model_fit_Random.predict(X_test)

# %%
Model_fit_Random.score(X_test, y_test)
# Out:
# 0.9789039140263615

# %%
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\rahma\miniconda3\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 44143.26252648643
# MSE: 66842748024.79656
# RMSE: 258539.64497692915

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.9789039140263615

# %%
import pickle
# open a file, where you ant to store the data
file = open('prediction.pkl', 'wb')

# dump information to that file
pickle.dump(Model_fit_Random, file)

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
